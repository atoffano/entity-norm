# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

# %% [markdown]
# BioSyn - Results

# %%
# Histogram
# x = ['Author', 'Reproduction']
# y = [91.1, 90.4687500000]
# y_errormin =[0, abs(y[1] - 90.1386356366)]
# y_errormax =[0, abs(y[1] - 90.7988643634)]
# y_error =[y_errormin, y_errormax]
# plt.ylim(90,92)
# plt.bar(x, y, yerr = y_error, color=[colors[1], colors[0]])
# plt.legend([], title="n=10")

# plt.title("BioSyn - Précision sur le jeu NCBI")
# plt.show() 

# As Boxplot
data = [90.20833333,89.89583333,91.35416667,90.10416667,90.52083333,91.14583333,90.10416667,90.41666667,90.52083333,90.41666667]
plt.figure(figsize = (3.5,5))
bp1 = plt.boxplot(data, notch = False, labels=['Reproduction (NCBI)'], widths = .4, patch_artist=True)
authors = plt.axhline(y=91.1, linestyle='--')
bp1['boxes'][0].set_facecolor(colors[0])
plt.legend([authors, bp1["boxes"][0]], ['Authors'], loc='upper right')
plt.ylabel('Accuracy', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
# Out:
# (array([89.8, 90. , 90.2, 90.4, 90.6, 90.8, 91. , 91.2, 91.4, 91.6]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#Plot Habitat

# Histogram
# x = ['BioSyn', 'BB4']
# y = [71.42, 62.71]
# y_errormin =[abs(y[0] - 70.5417279150767), abs(y[1] - 62.1390439090535)]
# y_errormax =[abs(y[0] - 72.2982720849233), abs(y[1] - 63.2809560909465)]
# y_error =[y_errormin, y_errormax]

# plt.ylim(60,75)
# plt.bar(x, y, yerr = y_error, color=[colors[0], colors[2]])
# plt.legend([], title="n=10")
# plt.title("Habitat")
# plt.show() 

## As Boxplot
# Habitat
biosyn = [63.9800,62.8200,62.5400,63.2100,62.1700,62.4900,62.6100,61.7400,61.7400,63.9200]
bb4 = [73.2594936709,71.3607594937,71.2025316456,71.6772151899,69.3037974684,71.3607594937,71.2025316500,71.0443037975,70.2531645570,73.4177215190]
data = [biosyn, bb4]
plt.figure(figsize = (3,5))
boxplots = plt.boxplot(data, notch = False, labels=['BioSyn','BB4'], widths = .5, patch_artist=True)
boxplots['boxes'][0].set_facecolor(colors[0])
boxplots['boxes'][1].set_facecolor(colors[2])
plt.title("Habitat", fontsize = 20)
plt.xlabel('Evaluateur', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)

# Phenotype
biosyn = [60.2484472050,61.4906832298,62.7329192547,62.1118012422,62.1118012422,61.4906832298,62.1118012422,62.7329192547,60.8695652174,63.9751552795]
bb4 = [54.0400000000,55.2800000000,56.5200000000,63.2100000000,55.9000000000,55.2800000000,55.9000000000,56.5200000000,54.6600000000,57.7600000000]
data = [biosyn, bb4]
plt.figure(figsize = (3,5))
boxplots = plt.boxplot(data, notch = False, labels=['BioSyn','BB4'], widths = .5, patch_artist=True)
boxplots['boxes'][0].set_facecolor(colors[0])
boxplots['boxes'][1].set_facecolor(colors[2])
plt.title("Phenotype", fontsize = 20)
plt.xlabel('Evaluateur', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
# Out:
# (array([52., 54., 56., 58., 60., 62., 64., 66.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#Plot global biosyn

# x = ['NCBI', 'BB4 - Phenotype', 'BB4 - Habitat']
# y = [90.4687500000, 73.59, 63.63]
# y_errormin =[abs(y[0] - 90.1386356366), abs(y[1] - 72.0472269623931), abs(y[2] - 60.2659693291645)]
# y_errormax =[abs(y[0] - 90.7988643634), abs(y[1] - 75.1327730376068), abs(y[2] - 66.9940306708355) ]
# y_error =[y_errormin, y_errormax]
# plt.ylim(0,100)
# plt.bar(x, y, yerr = y_error, color=[colors[0], colors[1], colors[2]])
# plt.legend([], title="n=10")
# plt.show() 

## As Boxplot
# Habitat
ncbi = [90.20833333,89.89583333,91.35416667,90.10416667,90.52083333,91.14583333,90.10416667,90.41666667,90.52083333,90.41666667]
habitat = [61.39,76.76,61.69,63.06,62.42,62.31,62.92,60.62,63.31,61.83]
phenotype = [72.35,73.15,73.54,73.94,70.50,70.90,77.25,75.53,72.75,75.93]
data = [ncbi, habitat, phenotype]
plt.figure(figsize = (4,5))
boxplots = plt.boxplot(data, notch = False, labels=['NCBI', 'Habitat', 'Phenotype'], widths = .6, patch_artist=True)
boxplots['boxes'][0].set_facecolor(colors[0])
boxplots['boxes'][1].set_facecolor(colors[3])
boxplots['boxes'][2].set_facecolor(colors[2])
plt.legend([boxplots["boxes"][0], boxplots["boxes"][1], boxplots['boxes'][2]], ['NCBI', 'Habitat', 'Phenotype'], loc='upper right')
plt.xlabel('Dataset', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
# Out:
# (array([55., 60., 65., 70., 75., 80., 85., 90., 95.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# Lightweight - Results

# %%
# Comparaison Préprocessing on NCBI
# x = ['Author', 'Reproduction\n(prétraité par défaut)', 'Reproduction\n             (prétraitement reproduit)']
# y = [89.59, 88.89, 76.31]
# y_errormin =[0, abs(y[1] - 81.844260997756), abs(y[2] - 75.6668672379931)]
# y_errormax =[0, abs(y[1] - 89.5955739002243), abs(y[2] - 76.9531327620069)]
# y_error =[y_errormin, y_errormax]
# plt.ylim(70,90)
# plt.bar(x, y, yerr = y_error, color=[colors[1], colors[0], colors[0]])
# plt.title("Reproduction et comparaison de l'effet du prétraitement sur le jeu NCBI")
# plt.legend([], title="n=10")
# plt.show() 

## As Boxplot
# Reproduction Lightweight
reprod_def = [88.345,88.450,88.033,89.906,88.762,89.906,89.386,89.906,89.282,86.889]
reprod_rec = [76.691,75.650,76.899,77.107,76.379,78.044,74.922,75.963,75.858,75.546]
data = [reprod_def, reprod_rec]
plt.figure(figsize = (6,5))

authors = plt.axhline(y=89.59, linestyle='--')
boxplots = plt.boxplot(data, notch = False, labels=['', ''], widths = .6, patch_artist=True)
boxplots['boxes'][0].set_facecolor(colors[0])
boxplots['boxes'][1].set_facecolor(colors[4])
plt.legend([authors, boxplots["boxes"][0], boxplots["boxes"][1]], ['Authors', 'Données fournies', 'Prétraitement reproduit'], loc='lower left')
plt.xlabel('Reproduction', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
# Out:
# (array([74., 76., 78., 80., 82., 84., 86., 88., 90., 92.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#Plot Phenotype
# x = ['Défaut\n(~5)', 'Classique\n(1)']
# y = [76.31, 76.06]
# y_errormin =[abs(y[0] - 75.7504474807439), abs(y[1] - 75.6668672379931)]
# y_errormax =[abs(y[0] - 76.3695525192561), abs(y[1] - 76.9531327620069)]

# y_error =[y_errormin, y_errormax]
# prop_cycle = plt.rcParams['axes.prop_cycle']
# colors = prop_cycle.by_key()['color']
# plt.ylim(75,78)
# plt.bar(x, y, yerr = y_error, color=[colors[0], colors[1]])
# plt.legend([], title="n=10")
# plt.title("Précision en fonction du nombre de passages sur chaque point du jeu d'entrainement")

# plt.show() 

## As Boxplot
# Comparaison steps per epoch
classic = [75.963,75.650,76.171,76.795,76.067,75.442,75.963,76.691,75.650,75.963]
default = [76.691,75.650,76.899,77.107,76.379,78.044,74.922,75.963,75.858,75.546]
data = [default, classic]
plt.figure(figsize = (6,5))

boxplots = plt.boxplot(data, notch = False, labels=['', ''], widths = .6, patch_artist=True)
boxplots['boxes'][0].set_facecolor(colors[0])
boxplots['boxes'][1].set_facecolor(colors[2])
plt.legend([boxplots["boxes"][0], boxplots["boxes"][1]], ['Default (~ 5 passages)', 'Classique (~ 1 passage)'], loc='upper right')
plt.xlabel('Reproduction', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
# Out:
# (array([74.5, 75. , 75.5, 76. , 76.5, 77. , 77.5, 78. , 78.5]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
## Lightweight Global Results
authors_ncbi = [88.345,88.450,88.033,89.906,88.762,89.906,89.386,89.906,89.282,86.889]
reprod_ncbi = [76.691,75.650,76.899,77.107,76.379,78.044,74.922,75.963,75.858,75.546]
phenotype = [60.05,61.64,60.85,64.02,62.04,62.04,59.66,66.80,61.64,61.24]
habitat = [46.18,46.13,59.80,45.66,46.38,47.03,46.10,45.69,46.94,46.34]
data = [authors_ncbi, reprod_ncbi, phenotype, habitat]
plt.figure(figsize = (8,5))
boxplots = plt.boxplot(data, notch = False, labels = ['', '', '', ''], widths = .6, patch_artist=True)
boxplots['boxes'][0].set_facecolor(colors[0])
boxplots['boxes'][1].set_facecolor(colors[4])
boxplots['boxes'][2].set_facecolor(colors[2])
boxplots['boxes'][3].set_facecolor(colors[3])
plt.legend([boxplots["boxes"][0], boxplots["boxes"][1], boxplots['boxes'][2], boxplots['boxes'][3]], ['NCBI (auteurs)', 'NCBI (reproduit)', 'Phenotype', 'Habitat'], loc='upper right')
plt.xlabel('Dataset', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
# Out:
# (array([ 40.,  50.,  60.,  70.,  80.,  90., 100.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
